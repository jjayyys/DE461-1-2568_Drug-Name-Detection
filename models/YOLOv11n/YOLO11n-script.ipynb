# %% [markdown]
# # <center>「YOLOv11n」The Drug Name Detection Dataset</center>
# ### <center>If you feel my notebook helpful, support with one upvote, thank you👍</center>

# %% [markdown]
# # <div style="border-radius:10px; border:#E75480 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:center">Import Libraries</div>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install ultralytics --quiet

# %%
import os
import yaml
import glob
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="darkgrid", font="SimHei", rc={"axes.unicode_minus":False})

import torch
from ultralytics import YOLO

from PIL import Image

seed = 1
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

# %% [markdown]
# # <div style="border-radius:10px; border:#E75480 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:center">Modeling</div>

# %%
model = YOLO("yolo11n.pt")

# %%
config = {
    "path": "/kaggle/input/the-drug-name-detection-dataset",
    "train": "/kaggle/input/the-drug-name-detection-dataset/train",
    "val": "/kaggle/input/the-drug-name-detection-dataset/valid",
    "test": "/kaggle/input/the-drug-name-detection-dataset/test",
    "nc": 1,
    "names": ["drug-name"],
}

with open("data.yaml", "w") as file:
    yaml.dump(config, file, default_flow_style=False)

# %%
# !wandb disabled
# Out:
# W&B disabled.

# %%
results = model.train(data="data.yaml", epochs=100, save_period=10, seed=seed, name="yolo11n")
# Out:
# Ultralytics 8.3.235 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolo11n, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/yolo11n, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=1, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# 2025-12-06 16:25:09,908	INFO util.py:129 -- Outdated packages:
#   ipywidgets==7.7.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 2025-12-06 16:25:10,073	INFO util.py:129 -- Outdated packages:
#   ipywidgets==7.7.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,035 parameters, 2,590,019 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 77.7±36.8 MB/s, size: 36.4 KB)
# train: Scanning /kaggle/input/the-drug-name-detection-dataset/train/labels... 1276 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1276/1276 1.0Kit/s 1.3s<0.1s
# WARNING ⚠️ train: Cache directory /kaggle/input/the-drug-name-detection-dataset/train is not writable, cache not saved.
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 182, len(boxes) = 1277. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: ImageCompression.__init__() got an unexpected keyword argument 'quality_range'
# val: Fast image access ✅ (ping: 1.7±1.7 ms, read: 54.0±9.7 MB/s, size: 27.1 KB)
# val: Scanning /kaggle/input/the-drug-name-detection-dataset/valid/labels... 365 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 365/365 423.6it/s 0.9s0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/the-drug-name-detection-dataset/valid is not writable, cache not saved.
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 44, len(boxes) = 364. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to /kaggle/working/runs/detect/yolo11n/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/detect/yolo11n
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.43G      1.874      3.704      1.623         18        640: 100% ━━━━━━━━━━━━ 80/80 4.3it/s 18.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.6it/s 2.1s0.2s
#                    all        365        364      0.247       0.17      0.141     0.0556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.79G      1.825      2.958      1.629         20        640: 100% ━━━━━━━━━━━━ 80/80 5.0it/s 16.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.2it/s 1.9s0.2s
#                    all        365        364      0.169      0.286      0.142     0.0562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.79G      1.871      2.608      1.687         28        640: 100% ━━━━━━━━━━━━ 80/80 5.1it/s 15.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.3it/s 1.9s0.2s
#                    all        365        364     0.0558      0.169     0.0391      0.014
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.79G      1.813      2.367      1.681         19        640: 100% ━━━━━━━━━━━━ 80/80 5.1it/s 15.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.8s0.2s
#                    all        365        364       0.22      0.146      0.081     0.0326
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.79G      1.817      2.306      1.683         22        640: 100% ━━━━━━━━━━━━ 80/80 5.1it/s 15.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.8s0.2s
#                    all        365        364      0.288      0.228       0.17     0.0651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.79G      1.721      2.176      1.589         19        640: 100% ━━━━━━━━━━━━ 80/80 5.1it/s 15.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1
640: 100% ━━━━━━━━━━━━ 80/80 5.2it/s 15.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.8it/s 1.8s0.2s
#                    all        365        364       0.75      0.594      0.711      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      2.79G      1.122       1.16      1.147         23        640: 100% ━━━━━━━━━━━━ 80/80 5.2it/s 15.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.8it/s 1.8s0.2s
#                    all        365        364      0.714      0.596      0.681      0.408
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      2.79G      1.095      1.111      1.124         26        640: 100% ━━━━━━━━━━━━ 80/80 5.2it/s 15.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.9it/s 1.7s0.2s
#                    all        365        364      0.704       0.67      0.706      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      2.79G        1.1      1.083      1.134         26        640: 100% ━━━━━━━━━━━━ 80/80 5.2it/s 15.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.7it/s 1.8s0.2s
#                    all        365        364      0.678      0.659      0.712      0.437
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      2.79G      1.109      1.118       1.13         23        640: 100% ━━━━━━━━━━━━ 80/80 5.2it/s 15.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.8it/s 1.8s0.2s
#                    all        365        364      0.678      0.654       0.71      0.452
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      2.79G      1.089      1.094      1.115         21        640: 100% ━━━━━━━━━━━━ 80/80 5.2it/s 15.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.7it/s 1.8s0.2s
#                    all        365        364      0.698      0.642      0.689      0.431
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      2.79G      1.088      1.092      1.124         20        640: 100% ━━━━━━━━━━━━ 80/80 5.1it/s 15.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.8s0.2s
#                    all        365        364      0.699      0.662      0.715      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      2.79G       1.07      1.084      1.117         23        640: 100% ━━━━━━━━━━━━ 80/80 5.1it/s 15.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.8it/s 1.8s0.2s
#                    all        365        364      0.755      0.632      0.727      0.452
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      2.79G      1.085      1.068      1.121         22        640: 100% ━━━━━━━━━━━━ 80/80 5.1it/s 15.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.7it/s 1.8s0.2s
#                    all        365        364      0.727      0.646      0.699      0.434
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      2.79G       1.06      1.052      1.107         20        640: 100% ━━━━━━━━━━━━ 80/80 5.2it/s 15.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.8it/s 1.8s0.2s
#                    all        365        364       0.68      0.654      0.679       0.42
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      2.79G      1.064      1.048      1.116         25        640: 100% ━━━━━━━━━━━━ 80/80 5.1it/s 15.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.2s
#                    all        365        364      0.752       0.64      0.712      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      2.79G      1.069      1.043      1.111         24        640: 100% ━━━━━━━━━━━━ 80/80 5.1it/s 15.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.2s
#                    all        365        364      0.731      0.666      0.727      0.436
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      2.79G      1.039      1.016      1.102         20        640: 100% ━━━━━━━━━━━━ 80/80 5.1it/s 15.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.9it/s 1.7s0.2s
#                    all        365        364      0.723      0.662      0.726      0.435
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      2.79G      1.065      1.033       1.11         22        640: 100% ━━━━━━━━━━━━ 80/80 5.1it/s 15.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.2s
#                    all        365        364      0.734      0.653      0.717      0.437
# Closing dataloader mosaic
# albumentations: ImageCompression.__init__() got an unexpected keyword argument 'quality_range'
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      2.79G      0.998     0.9284      1.072         12        640: 100% ━━━━━━━━━━━━ 80/80 4.5it/s 17.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.8it/s 1.8s0.2s
#                    all        365        364      0.723      0.637      0.698      0.413
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      2.79G     0.9944     0.8908      1.078         13        640: 100% ━━━━━━━━━━━━ 80/80 5.2it/s 15.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.7it/s 1.8s0.2s
#                    all        365        364      0.739      0.624      0.704      0.417
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      2.79G     0.9869      0.883      1.065         12        640: 100% ━━━━━━━━━━━━ 80/80 5.2it/s 15.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.7it/s 1.8s0.2s
#                    all        365        364      0.732      0.667      0.718      0.431
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      2.79G     0.9788      0.857       1.06         12        640: 100% ━━━━━━━━━━━━ 80/80 5.1it/s 15.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.2s
#                    all        365        364      0.713      0.703      0.737      0.444
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      2.79G      0.963     0.8537      1.052         12        640: 100% ━━━━━━━━━━━━ 80/80 5.2it/s 15.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 7.0it/s 1.7s0.2s
#                    all        365        364      0.769      0.659      0.734      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      2.79G     0.9642     0.8272      1.066         12        640: 100% ━━━━━━━━━━━━ 80/80 5.1it/s 15.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.4it/s 1.9s0.2s
#                    all        365        364      0.742      0.676      0.743       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      2.79G     0.9589     0.8332      1.056         12        640: 100% ━━━━━━━━━━━━ 80/80 5.1it/s 15.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.8s0.2s
#                    all        365        364      0.744      0.654      0.734      0.447
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      2.79G     0.9431     0.8195      1.043         11        640: 100% ━━━━━━━━━━━━ 80/80 5.2it/s 15.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.2s
#                    all        365        364      0.693      0.712      0.735      0.449
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      2.79G     0.9323     0.8116      1.038         11        640: 100% ━━━━━━━━━━━━ 80/80 5.2it/s 15.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.2s
#                    all        365        364      0.754      0.648       0.73      0.442
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      2.79G     0.9451     0.8059      1.042         13        640: 100% ━━━━━━━━━━━━ 80/80 5.1it/s 15.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.8s0.2s
#                    all        365        364      0.729      0.681      0.736      0.447
#
# 100 epochs completed in 0.490 hours.
# Optimizer stripped from /kaggle/working/runs/detect/yolo11n/weights/last.pt, 5.5MB
# Optimizer stripped from /kaggle/working/runs/detect/yolo11n/weights/best.pt, 5.5MB
#
# Validating /kaggle/working/runs/detect/yolo11n/weights/best.pt...
# Ultralytics 8.3.235 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.9it/s 4.2s0.2s
#                    all        365        364      0.757      0.632      0.727      0.453
# Speed: 0.7ms preprocess, 3.1ms inference, 0.0ms loss, 4.6ms postprocess per image
# Results saved to /kaggle/working/runs/detect/yolo11n

# %%
Image.open("/kaggle/working/runs/detect/yolo11n/results.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2400x1200>

# %%
# Export and Save Model for further uses
import shutil

# Path of model (best.pt)
# Normally at: runs/detect/{name}/weights/best.pt
best_model_path = "runs/detect/yolo11n/weights/best.pt"
output_model_name = "yolo11n_best_model.pt"

if os.path.exists(best_model_path):
    # Copy to path for easier to download/use
    shutil.copy(best_model_path, output_model_name)
    print(f"Successfully! Saved model at: {output_model_name}")
    print("You can use this model for Prediction.")
else:
    print("Model not found, please check the path.")

# (Optional) If you want Export to other format (e.g., ONNX)
# success = model.export(format='onnx')
# Out:
# Successfully! Saved model at: yolo11n_best_model.pt
# You can use this model for Prediction.

# %%
# Validate on the 'test' split specifically
metrics = model.val(split='test')
# Out:
# Ultralytics 8.3.235 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 2.6±1.3 ms, read: 34.7±29.9 MB/s, size: 27.8 KB)
# val: Scanning /kaggle/input/the-drug-name-detection-dataset/test/labels... 182 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 182/182 506.0it/s 0.4s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/the-drug-name-detection-dataset/test is not writable, cache not saved.
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 25, len(boxes) = 182. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.2it/s 3.8s0.1s
#                    all        182        182      0.608      0.656      0.689       0.45
# Speed: 2.5ms preprocess, 6.5ms inference, 0.0ms loss, 3.9ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val3

# %%
# Extract key metrics
map50 = metrics.box.map50
map50_95 = metrics.box.map
precision = metrics.box.mp
recall = metrics.box.mr

# Calculate F1-Score manually (Harmonic Mean of Precision and Recall)
# Formula: F1 = 2 * (P * R) / (P + R)
f1_score = 0.0
if (precision + recall) > 0:
    f1_score = 2 * (precision * recall) / (precision + recall)

print("\n" + "="*40)
print("   MODEL PERFORMANCE METRICS on {TEST SET}")
print("="*40)
print(f"mAP@50       : {map50:.4f}")
print(f"mAP@50-95    : {map50_95:.4f}")
print(f"Precision    : {precision:.4f}")
print(f"Recall       : {recall:.4f}")
print(f"F1-Score     : {f1_score:.4f}")
print("="*40 + "\n")
# Out:
# ========================================
#    MODEL PERFORMANCE METRICS on {TEST SET}
# ========================================
# mAP@50       : 0.6889
# mAP@50-95    : 0.4495
# Precision    : 0.6078
# Recall       : 0.6555
# F1-Score     : 0.6307
# ========================================

# %% [markdown]
# # <div style="border-radius:10px; border:#E75480 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:center">Predict Test Data</div>

# %%
paths = glob.glob("/kaggle/input/the-drug-name-detection-dataset/test/images/*")

# %%
n = 10
results = model.predict(paths[:n])
for i in range(n):
    r = results[i]
    img = Image.fromarray(r.plot())
    plt.figure(dpi=100)
    plt.imshow(img)
    plt.axis("off")
    plt.tight_layout()
    plt.show()
# Out:
# 0: 640x640 2 drug-names, 7.5ms
# 1: 640x640 2 drug-names, 7.5ms
# 2: 640x640 1 drug-name, 7.5ms
# 3: 640x640 1 drug-name, 7.5ms
# 4: 640x640 1 drug-name, 7.5ms
# 5: 640x640 (no detections), 7.5ms
# 6: 640x640 2 drug-names, 7.5ms
# 7: 640x640 2 drug-names, 7.5ms
# 8: 640x640 2 drug-names, 7.5ms
# 9: 640x640 1 drug-name, 7.5ms
# Speed: 1.9ms preprocess, 7.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
