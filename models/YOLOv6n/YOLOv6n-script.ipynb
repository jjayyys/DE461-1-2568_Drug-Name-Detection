# %% [markdown]
# # <center>「YOLOv6n」The Drug Name Detection Dataset</center>
# ### <center>If you feel my notebook helpful, support with one upvote, thank you👍</center>

# %% [markdown]
# # <div style="border-radius:10px; border:#E75480 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:center">Import Libraries</div>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install ultralytics --quiet

# %%
import os
import yaml
import glob
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="darkgrid", font="SimHei", rc={"axes.unicode_minus":False})

import torch
from ultralytics import YOLO

from PIL import Image

seed = 1
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

# %% [markdown]
# # <div style="border-radius:10px; border:#E75480 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:center">Modeling</div>

# %%
model = YOLO("yolov6n.yaml")

# %%
config = {
    "path": "/kaggle/input/the-drug-name-detection-dataset",
    "train": "/kaggle/input/the-drug-name-detection-dataset/train",
    "val": "/kaggle/input/the-drug-name-detection-dataset/valid",
    "test": "/kaggle/input/the-drug-name-detection-dataset/test",
    "nc": 1,
    "names": ["drug-name"],
}

with open("data.yaml", "w") as file:
    yaml.dump(config, file, default_flow_style=False)

# %%
# !wandb disabled
# Out:
# W&B disabled.

# %%
results = model.train(data="data.yaml", epochs=100, save_period=10, seed=seed, name="yolov6n")
# Out:
# Ultralytics 8.3.235 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov6n.yaml, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov6n, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/yolov6n, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=1, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# 2025-12-06 15:50:27,602	INFO util.py:129 -- Outdated packages:
#   ipywidgets==7.7.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 2025-12-06 15:50:27,769	INFO util.py:129 -- Outdated packages:
#   ipywidgets==7.7.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# Overriding model.yaml nc=80 with nc=1
# activation: torch.nn.ReLU()
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  2     18560  ultralytics.nn.modules.conv.Conv             [32, 32, 3, 1]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  4    147968  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 1]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  6    886272  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 1]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  2   1180672  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 1]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1     16512  ultralytics.nn.modules.conv.Conv             [256, 64, 1, 1]
#  11                  -1  1     16448  torch.nn.modules.conv.ConvTranspose2d        [64, 64, 2, 2, 0]
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    110720  ultralytics.nn.modules.conv.Conv             [192, 64, 3, 1]
#  14                  -1  3    110976  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 1]
#  15                  -1  1      2112  ultralytics.nn.modules.conv.Conv             [64, 32, 1, 1]
#  16                  -1  1      4128  torch.nn.modules.conv.ConvTranspose2d        [32, 32, 2, 2, 0]
#  17             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1     27712  ultralytics.nn.modules.conv.Conv             [96, 32, 3, 1]
#  19                  -1  3     27840  ultralytics.nn.modules.conv.Conv             [32, 32, 3, 1]
#  20                  -1  1      9280  ultralytics.nn.modules.conv.Conv             [32, 32, 3, 2]
#  21            [-1, 15]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 1]
#  23                  -1  3    110976  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 1]
#  24                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  25            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  26                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 1]
#  27                  -1  3    443136  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 1]
#  28        [19, 23, 27]  1    345523  ultralytics.nn.modules.head.Detect           [1, [32, 64, 128]]
# YOLOv6n summary: 121 layers, 4,238,243 parameters, 4,238,227 gradients, 11.8 GFLOPs
#
# Freezing layer 'model.28.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 87.8±32.6 MB/s, size: 36.4 KB)
# train: Scanning /kaggle/input/the-drug-name-detection-dataset/train/labels... 1276 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1276/1276 1.0Kit/s 1.3s<0.1s
# WARNING ⚠️ train: Cache directory /kaggle/input/the-drug-name-detection-dataset/train is not writable, cache not saved.
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 182, len(boxes) = 1277. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: ImageCompression.__init__() got an unexpected keyword argument 'quality_range'
# val: Fast image access ✅ (ping: 2.9±2.6 ms, read: 47.4±13.1 MB/s, size: 27.1 KB)
# val: Scanning /kaggle/input/the-drug-name-detection-dataset/valid/labels... 365 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 365/365 430.6it/s 0.8s0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/the-drug-name-detection-dataset/valid is not writable, cache not saved.
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 44, len(boxes) = 364. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to /kaggle/working/runs/detect/yolov6n/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 53 weight(decay=0.0), 62 weight(decay=0.0005), 61 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/detect/yolov6n
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      1.91G       4.12      5.285      4.042         18        640: 100% ━━━━━━━━━━━━ 80/80 4.9it/s 16.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.0it/s 2.0s0.2s
#                    all        365        364   0.000183     0.0549   9.67e-05   2.23e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      1.91G      3.314      3.769      3.226         20        640: 100% ━━━━━━━━━━━━ 80/80 5.8it/s 13.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.7it/s 1.8s0.2s
#                    all        365        364    0.00143      0.286    0.00329   0.000738
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      1.91G      2.955      3.337      2.945         28        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 4.5it/s 2.6s0.2s
#                    all        365        364   0.000468     0.0385    0.00021   6.48e-05
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      1.91G      2.773      3.078      2.806         19        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.4it/s 1.9s0.2s
#                    all        365        364     0.0569      0.033    0.00555    0.00128
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      1.91G      2.658      3.022      2.705         22        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.7it/s 1.8s0.2s
#                    all        365        364     0.0914     0.0687     0.0283    0.00825
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      1.91G      2.529      2.851       2.58         19        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.4it/s 1.9s0.2s
#                    all        365        364     0.0789     0.0962     0.0316    0.00886
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      1.91G      2.397      2.761      2.497         22        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.2s
#                    all        365        364     0.0513     0.0577     0.0151    0.00443
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      1.91G      2.336      2.654      2.439         19        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.8it/s 1.8s0.2s
#                    all        365        364      0.235      0.313      0.174     0.0656
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      1.91G      2.272      2.613      2.394         18        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.9s0.2s
#                    all        365        364      0.197      0.157     0.0998     0.0305
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      1.91G      2.277      2.622      2.362         14        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.7it/s 1.8s0.2s
#                    all        365        364      0.191      0.272      0.136     0.0533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      1.91G      2.231      2.533      2.317         18        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.4it/s 1.9s0.2s
#                    all        365        364      0.184      0.258      0.128     0.0449
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      1.91G      2.172      2.445       2.23         21        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.7it/s 1.8s0.2s
#                    all        365        364      0.315      0.261      0.182     0.0769
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      1.91G      2.059      2.463      2.185         22        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.2s
#                    all        365        364      0.248      0.272      0.182     0.0798
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      1.91G       2.02      2.386      2.131         24        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.8s0.2s
#                    all        365        364      0.316      0.283      0.238      0.105
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      1.91G      1.992      2.364      2.112         18        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.9s0.2s
#                    all        365        364       0.29      0.233      0.152     0.0649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      1.91G      1.985      2.354      2.057         22        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.8s0.2s
#                    all        365        364      0.248      0.213      0.138     0.0603
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      1.91G      1.947      2.348      2.061         20        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.4it/s 1.9s0.2s
#                    all        365        364      0.282      0.212      0.168     0.0733
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      1.91G      1.991       2.31      2.081         16        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.9s0.2s
#                    all        365        364      0.304      0.354      0.222     0.0965
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      1.91G      1.932      2.316      2.015         22        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.8s0.2s
#                    all        365        364      0.268      0.341      0.232      0.115
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      1.91G       1.85      2.187      1.977         13        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.3it/s 1.9s0.2s
#                    all        365        364      0.346      0.283       0.26      0.127
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      1.91G      1.863      2.225      1.992         21        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.2s
#                    all        365        364      0.323      0.327       0.27      0.138
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      1.91G       1.83      2.224       1.93         23        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.2it/s 1.9s0.2s
#                    all        365        364      0.134      0.195     0.0669      0.028
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      1.91G      1.818      2.182       1.93         22        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.7it/s 1.8s0.1s
#                    all        365        364      0.297      0.343      0.251      0.119
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      1.91G      1.798      2.155      1.903         23        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.9s0.2s
#                    all        365        364      0.313       0.34      0.234      0.102
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      1.91G      1.766      2.103      1.879         20        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.4it/s 1.9s0.2s
#                    all        365        364      0.278      0.283       0.19     0.0879
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      1.91G      1.817      2.166      1.915         17        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.8s0.2s
#                    all        365        364      0.324      0.385      0.296      0.151
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      1.91G      1.818      2.149      1.878         18        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.8s0.2s
#                    all        365        364      0.354      0.348      0.296      0.144
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      1.91G      1.785      2.127      1.867         19        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.3it/s 1.9s0.2s
#                    all        365        364      0.271      0.371      0.226      0.118
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      1.91G      1.703      2.055      1.828         21        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.1s
#                    all        365        364      0.299      0.327      0.237      0.114
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      1.91G      1.721      2.034      1.838         11        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.3it/s 1.9s0.2s
#                    all        365        364      0.305      0.379      0.269      0.131
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      1.91G      1.735      2.091      1.841         25        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.7it/s 1.8s0.1s
#                    all        365        364      0.378      0.398      0.337      0.177
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      1.91G      1.712      2.046       1.81         22        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.3it/s 1.9s0.2s
#                    all        365        364       0.36      0.341       0.28      0.132
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      1.91G      1.738      2.039      1.806         23        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.8s0.2s
#                    all        365        364       0.42      0.366      0.325      0.176
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      1.91G      1.679      1.992      1.789         25        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.3it/s 1.9s0.2s
#                    all        365        364      0.406      0.379      0.312      0.158
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      1.91G      1.667      2.018      1.782         24        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.4it/s 1.9s0.2s
#                    all        365        364      0.397      0.462      0.378      0.211
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      1.91G      1.679      1.997      1.787         25        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.4it/s 1.9s0.2s
#                    all        365        364      0.386      0.404      0.317      0.157
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      1.91G      1.634      1.998       1.74         28        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.9s0.2s
#                    all        365        364      0.374      0.398       0.33      0.171
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      1.91G      1.651      1.997      1.755         12        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.4it/s 1.9s0.2s
#                    all        365        364       0.36      0.299      0.256      0.113
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      1.91G      1.682      1.989      1.755         13        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.9s0.2s
#                    all        365        364       0.41      0.447      0.349      0.199
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      1.91G      1.624      1.945      1.734         14        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.4it/s 1.9s0.2s
#                    all        365        364      0.387       0.42      0.338      0.169
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      1.91G      1.616      1.917      1.735         22        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.8s0.2s
#                    all        365        364      0.392      0.387      0.346      0.185
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      1.91G      1.657      1.931      1.755         26        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.2it/s 1.9s0.2s
#                    all        365        364      0.343      0.472      0.325      0.173
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      1.91G      1.606       1.92      1.725         24        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.4it/s 1.9s0.2s
#                    all        365        364      0.386      0.536      0.399      0.213
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      1.91G      1.605      1.911       1.71         21        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.9s0.2s
#                    all        365        364      0.394      0.407      0.368      0.194
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      1.91G      1.581      1.885      1.668         21        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.3it/s 1.9s0.2s
#                    all        365        364      0.409      0.456      0.368      0.192
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      1.91G      1.565      1.803      1.688         17        640: 100% ━━━━━━━━━━━━ 80/80 5.8it/s 13.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.9s0.2s
#                    all        365        364      0.447      0.353      0.319      0.152
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      1.91G      1.551      1.898      1.681         21        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.8s0.2s
#                    all        365        364      0.388      0.379      0.347      0.179
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      1.91G      1.606      1.902      1.699         17        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.3it/s 1.9s0.2s
#                    all        365        364      0.477      0.451       0.39      0.215
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      1.91G       1.53      1.868      1.661         21        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.2s
#                    all        365        364      0.477      0.451      0.433      0.243
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      1.91G      1.528       1.82      1.645         13        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.7it/s 1.8s0.2s
#                    all        365        364      0.437      0.473      0.388      0.203
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      1.91G      1.571       1.85      1.654         14        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.2s
#                    all        365        364        0.4      0.401      0.375      0.185
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      1.91G      1.538       1.79      1.665         20        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.2s
#                    all        365        364      0.472      0.462      0.442      0.239
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      1.91G      1.517       1.77      1.641         20        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.7it/s 1.8s0.2s
#                    all        365        364      0.439      0.477       0.43      0.237
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      1.91G       1.56      1.794      1.657         14        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.8s0.2s
#                    all        365        364      0.447      0.456      0.425      0.221
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      1.91G       1.56      1.796      1.671         14        640: 100% ━━━━━━━━━━━━ 80/80 5.8it/s 13.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.4it/s 1.9s0.2s
#                    all        365        364      0.487      0.428      0.436      0.246
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      1.91G      1.586      1.807      1.685         25        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.8s0.2s
#                    all        365        364      0.434      0.421      0.379      0.181
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      1.91G      1.529      1.786      1.661         21        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.9s0.2s
#                    all        365        364      0.443      0.511       0.41      0.227
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      1.91G      1.543      1.767      1.641         11        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.4it/s 1.9s0.2s
#                    all        365        364      0.412      0.442      0.389      0.203
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      1.91G       1.52      1.742      1.636         20        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.2s
#                    all        365        364      0.557       0.42      0.438      0.255
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      1.91G      1.528      1.775      1.637         13        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.4it/s 1.9s0.2s
#                    all        365        364      0.419      0.423      0.406      0.213
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      1.91G      1.514       1.76      1.635         17        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.2s
#                    all        365        364      0.494      0.502      0.461      0.254
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      1.91G      1.503      1.745      1.631         15        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.9s0.2s
#                    all        365        364      0.487      0.464      0.454      0.266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      1.91G       1.47      1.689      1.607         14        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.2s
#                    all        365        364      0.451      0.552      0.467      0.276
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      1.91G      1.475      1.714      1.618         17        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.9s0.2s
#                    all        365        364      0.475      0.456      0.445      0.254
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      1.91G        1.5      1.724      1.614         15        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.2s
#                    all        365        364      0.487      0.545      0.488      0.275
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      1.91G      1.468      1.713      1.601         27        640: 100% ━━━━━━━━━━━━ 80/80 6.0it/s 13.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.2s
#                    all        365        364      0.477      0.459      0.435      0.238
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      1.91G      1.491      1.694      1.607         20        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.9s0.2s
#                    all        365        364      0.503      0.495      0.492      0.282
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      1.91G       1.49       1.72       1.58         16        640: 100% ━━━━━━━━━━━━ 80/80 6.0it/s 13.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.2s
#                    all        365        364      0.459      0.505      0.475      0.279
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      1.91G      1.448      1.676       1.58         17        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.8s0.2s
#                    all        365        364      0.511        0.5      0.504      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      1.91G      1.465      1.691      1.572         24        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.9s0.2s
#                    all        365        364        0.5      0.522      0.493      0.275
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      1.91G      1.462      1.698      1.568         19        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.7it/s 1.8s0.2s
#                    all        365        364      0.541      0.497      0.499      0.292
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      1.91G      1.424      1.647      1.569         23        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.8it/s 1.8s0.1s
#                    all        365        364      0.546      0.467      0.513      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      1.91G      1.467      1.654      1.598         14        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.8s0.2s
#                    all        365        364      0.563        0.5      0.519       0.29
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      1.91G      1.459      1.636      1.578         14        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.8s0.2s
#                    all        365        364      0.509      0.523       0.49       0.28
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      1.91G      1.456      1.644      1.583         25        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.7it/s 1.8s0.2s
#                    all        365        364      0.578      0.478      0.521      0.298
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      1.91G      1.418      1.598      1.539         22        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.9s0.2s
#                    all        365        364      0.497      0.527      0.503      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      1.91G      1.418      1.608       1.55         24        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.4it/s 1.9s0.2s
#                    all        365        364      0.504      0.473      0.466      0.266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      1.91G      1.411      1.597       1.54         23        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.8it/s 1.8s0.2s
#                    all        365        364      0.542      0.511      0.522      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      1.91G      1.378      1.614      1.526         26        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.7it/s 1.8s0.2s
#                    all        365        364      0.521      0.525      0.516        0.3
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      1.91G      1.427      1.561       1.55         26        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.8s0.2s
#                    all        365        364      0.549      0.478      0.504      0.292
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      1.91G      1.403      1.586      1.515         23        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.2s
#                    all        365        364      0.497      0.541       0.53      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      1.91G      1.384      1.563      1.513         21        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.8s0.2s
#                    all        365        364      0.573       0.53      0.551      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      1.91G      1.385       1.59      1.531         20        640: 100% ━━━━━━━━━━━━ 80/80 6.0it/s 13.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.2s
#                    all        365        364      0.556      0.538      0.528      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      1.91G      1.374      1.564      1.525         23        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.8s0.2s
#                    all        365        364      0.537      0.574      0.554       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      1.91G        1.4      1.548      1.523         22        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.4it/s 1.9s0.2s
#                    all        365        364       0.57      0.492      0.542      0.318
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      1.91G      1.369      1.546      1.505         20        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.7it/s 1.8s0.2s
#                    all        365        364      0.564      0.514      0.544      0.325
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      1.91G      1.367      1.514       1.51         25        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.9it/s 1.8s0.2s
#                    all        365        364      0.529      0.552      0.556       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      1.91G      1.376      1.529      1.505         24        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.7it/s 1.8s0.2s
#                    all        365        364      0.566       0.54      0.559      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      1.91G      1.359      1.487      1.515         20        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.7it/s 1.8s0.2s
#                    all        365        364      0.592      0.494      0.531      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      1.91G       1.37      1.519      1.523         22        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.7it/s 1.8s0.2s
#                    all        365        364      0.562      0.553       0.55      0.324
# Closing dataloader mosaic
# albumentations: ImageCompression.__init__() got an unexpected keyword argument 'quality_range'
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      1.91G       1.35      1.482      1.476         12        640: 100% ━━━━━━━━━━━━ 80/80 5.2it/s 15.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.7it/s 1.8s0.2s
#                    all        365        364      0.592      0.502      0.562      0.326
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      1.91G      1.339      1.429      1.475         13        640: 100% ━━━━━━━━━━━━ 80/80 6.0it/s 13.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.7it/s 1.8s0.2s
#                    all        365        364      0.542      0.554       0.53        0.3
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      1.91G      1.317       1.43      1.444         12        640: 100% ━━━━━━━━━━━━ 80/80 6.0it/s 13.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.2s
#                    all        365        364      0.569      0.585      0.585       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      1.91G      1.327      1.409      1.439         12        640: 100% ━━━━━━━━━━━━ 80/80 6.0it/s 13.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.7it/s 1.8s0.2s
#                    all        365        364      0.568      0.563      0.568      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      1.91G      1.302      1.374      1.417         12        640: 100% ━━━━━━━━━━━━ 80/80 6.0it/s 13.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.2s
#                    all        365        364      0.582      0.552      0.583      0.353
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      1.91G      1.318      1.395       1.44         12        640: 100% ━━━━━━━━━━━━ 80/80 6.0it/s 13.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.2s
#                    all        365        364      0.605      0.541      0.584      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      1.91G      1.313      1.395      1.439         12        640: 100% ━━━━━━━━━━━━ 80/80 6.0it/s 13.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.9s0.2s
#                    all        365        364      0.597      0.555       0.59      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      1.91G      1.296      1.375       1.44         11        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.5it/s 1.8s0.2s
#                    all        365        364      0.579      0.558       0.59      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      1.91G      1.296      1.376      1.423         11        640: 100% ━━━━━━━━━━━━ 80/80 5.9it/s 13.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.7it/s 1.8s0.2s
#                    all        365        364      0.575      0.563      0.587      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      1.91G      1.307      1.344      1.438         13        640: 100% ━━━━━━━━━━━━ 80/80 6.0it/s 13.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.6it/s 1.8s0.2s
#                    all        365        364      0.578      0.588      0.589      0.349
#
# 100 epochs completed in 0.438 hours.
# Optimizer stripped from /kaggle/working/runs/detect/yolov6n/weights/last.pt, 8.7MB
# Optimizer stripped from /kaggle/working/runs/detect/yolov6n/weights/best.pt, 8.7MB
#
# Validating /kaggle/working/runs/detect/yolov6n/weights/best.pt...
# Ultralytics 8.3.235 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLOv6n summary (fused): 68 layers, 4,233,843 parameters, 0 gradients, 11.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.0it/s 4.0s0.2s
#                    all        365        364      0.583      0.549      0.584      0.354
# Speed: 0.9ms preprocess, 2.6ms inference, 0.0ms loss, 3.5ms postprocess per image
# Results saved to /kaggle/working/runs/detect/yolov6n

# %%
Image.open("/kaggle/working/runs/detect/yolov6n/results.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2400x1200>

# %%
# Export and Save Model for further uses
import shutil

# Path of model (best.pt)
# Normally at: runs/detect/{name}/weights/best.pt
best_model_path = "runs/detect/yolov6n/weights/best.pt"
output_model_name = "yolov6n_best_model.pt"

if os.path.exists(best_model_path):
    # Copy to path for easier to download/use
    shutil.copy(best_model_path, output_model_name)
    print(f"Successfully! Saved model at: {output_model_name}")
    print("You can use this model for Prediction.")
else:
    print("Model not found, please check the path.")

# (Optional) If you want Export to other format (e.g., ONNX)
# success = model.export(format='onnx')
# Out:
# Successfully! Saved model at: yolov6n_best_model.pt
# You can use this model for Prediction.

# %%
# Validate on the 'test' split specifically
metrics = model.val(split='test')
# Out:
# Ultralytics 8.3.235 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLOv6n summary (fused): 68 layers, 4,233,843 parameters, 0 gradients, 11.7 GFLOPs
# val: Fast image access ✅ (ping: 1.1±0.1 ms, read: 65.9±32.7 MB/s, size: 27.8 KB)
# val: Scanning /kaggle/input/the-drug-name-detection-dataset/test/labels... 182 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 182/182 685.6it/s 0.3s0.2s
# WARNING ⚠️ val: Cache directory /kaggle/input/the-drug-name-detection-dataset/test is not writable, cache not saved.
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 25, len(boxes) = 182. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.2it/s 3.8s0.1s
#                    all        182        182      0.675      0.522      0.598      0.363
# Speed: 3.3ms preprocess, 7.1ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val2

# %%
# Extract key metrics
map50 = metrics.box.map50
map50_95 = metrics.box.map
precision = metrics.box.mp
recall = metrics.box.mr

# Calculate F1-Score manually (Harmonic Mean of Precision and Recall)
# Formula: F1 = 2 * (P * R) / (P + R)
f1_score = 0.0
if (precision + recall) > 0:
    f1_score = 2 * (precision * recall) / (precision + recall)

print("\n" + "="*40)
print("   MODEL PERFORMANCE METRICS on {TEST SET}")
print("="*40)
print(f"mAP@50       : {map50:.4f}")
print(f"mAP@50-95    : {map50_95:.4f}")
print(f"Precision    : {precision:.4f}")
print(f"Recall       : {recall:.4f}")
print(f"F1-Score     : {f1_score:.4f}")
print("="*40 + "\n")
# Out:
# ========================================
#    MODEL PERFORMANCE METRICS on {TEST SET}
# ========================================
# mAP@50       : 0.5976
# mAP@50-95    : 0.3631
# Precision    : 0.6748
# Recall       : 0.5220
# F1-Score     : 0.5886
# ========================================

# %% [markdown]
# # <div style="border-radius:10px; border:#E75480 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:center">Predict Test Data</div>

# %%
paths = glob.glob("/kaggle/input/the-drug-name-detection-dataset/test/images/*")

# %%
n = 10
results = model.predict(paths[:n])
for i in range(n):
    r = results[i]
    img = Image.fromarray(r.plot())
    plt.figure(dpi=100)
    plt.imshow(img)
    plt.axis("off")
    plt.tight_layout()
    plt.show()
# Out:
# 0: 640x640 3 drug-names, 6.4ms
# 1: 640x640 1 drug-name, 6.4ms
# 2: 640x640 1 drug-name, 6.4ms
# 3: 640x640 1 drug-name, 6.4ms
# 4: 640x640 (no detections), 6.4ms
# 5: 640x640 1 drug-name, 6.4ms
# 6: 640x640 2 drug-names, 6.4ms
# 7: 640x640 1 drug-name, 6.4ms
# 8: 640x640 1 drug-name, 6.4ms
# 9: 640x640 1 drug-name, 6.4ms
# Speed: 1.9ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
