# %% [markdown]
# # <center>「YOLOv9t」The Drug Name Detection Dataset</center>
# ### <center>If you feel my notebook helpful, support with one upvote, thank you👍</center>

# %% [markdown]
# # <div style="border-radius:10px; border:#E75480 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:center">Import Libraries</div>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install ultralytics --quiet

# %%
import os
import yaml
import glob
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="darkgrid", font="SimHei", rc={"axes.unicode_minus":False})

import torch
from ultralytics import YOLO

from PIL import Image

seed = 1
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

# %% [markdown]
# # <div style="border-radius:10px; border:#E75480 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:center">Modeling</div>

# %%
model = YOLO("yolov9t.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov9t.pt to 'yolov9t.pt': 100% ━━━━━━━━━━━━ 4.7MB 60.0MB/s 0.1s

# %%
config = {
    "path": "/kaggle/input/the-drug-name-detection-dataset",
    "train": "/kaggle/input/the-drug-name-detection-dataset/train",
    "val": "/kaggle/input/the-drug-name-detection-dataset/valid",
    "test": "/kaggle/input/the-drug-name-detection-dataset/test",
    "nc": 1,
    "names": ["drug-name"],
}

with open("data.yaml", "w") as file:
    yaml.dump(config, file, default_flow_style=False)

# %%
# !wandb disabled
# Out:
# W&B disabled.

# %%
results = model.train(data="data.yaml", epochs=100, save_period=10, seed=seed, name="yolov9t")
# Out:
# Ultralytics 8.3.235 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov9t.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov9t, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/yolov9t, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=1, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# 2025-12-06 18:53:32,295	INFO util.py:129 -- Outdated packages:
#   ipywidgets==7.7.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 2025-12-06 18:53:32,450	INFO util.py:129 -- Outdated packages:
#   ipywidgets==7.7.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7872  ultralytics.nn.modules.block.ELAN1           [32, 32, 32, 16]
#   3                  -1  1     18560  ultralytics.nn.modules.block.AConv           [32, 64]
#   4                  -1  1     65216  ultralytics.nn.modules.block.RepNCSPELAN4    [64, 64, 64, 32, 3]
#   5                  -1  1     55488  ultralytics.nn.modules.block.AConv           [64, 96]
#   6                  -1  1    145824  ultralytics.nn.modules.block.RepNCSPELAN4    [96, 96, 96, 48, 3]
#   7                  -1  1    110848  ultralytics.nn.modules.block.AConv           [96, 128]
#   8                  -1  1    258432  ultralytics.nn.modules.block.RepNCSPELAN4    [128, 128, 128, 64, 3]
#   9                  -1  1     41344  ultralytics.nn.modules.block.SPPELAN         [128, 128, 64]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    158112  ultralytics.nn.modules.block.RepNCSPELAN4    [224, 96, 96, 48, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     71360  ultralytics.nn.modules.block.RepNCSPELAN4    [160, 64, 64, 32, 3]
#  16                  -1  1     27744  ultralytics.nn.modules.block.AConv           [64, 48]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    150432  ultralytics.nn.modules.block.RepNCSPELAN4    [144, 96, 96, 48, 3]
#  19                  -1  1     55424  ultralytics.nn.modules.block.AConv           [96, 64]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    266624  ultralytics.nn.modules.block.RepNCSPELAN4    [192, 128, 128, 64, 3]
#  22        [15, 18, 21]  1    567187  ultralytics.nn.modules.head.Detect           [1, [64, 96, 128]]
# YOLOv9t summary: 544 layers, 2,005,603 parameters, 2,005,587 gradients, 7.8 GFLOPs
#
# Transferred 1303/1339 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 98.8±23.6 MB/s, size: 36.4 KB)
# train: Scanning /kaggle/input/the-drug-name-detection-dataset/train/labels... 1276 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1276/1276 1.0Kit/s 1.2s0.0s
# WARNING ⚠️ train: Cache directory /kaggle/input/the-drug-name-detection-dataset/train is not writable, cache not saved.
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 182, len(boxes) = 1277. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: ImageCompression.__init__() got an unexpected keyword argument 'quality_range'
# val: Fast image access ✅ (ping: 1.6±0.1 ms, read: 65.3±16.6 MB/s, size: 27.1 KB)
# val: Scanning /kaggle/input/the-drug-name-detection-dataset/valid/labels... 365 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 365/365 385.0it/s 0.9s0.0s
# WARNING ⚠️ val: Cache directory /kaggle/input/the-drug-name-detection-dataset/valid is not writable, cache not saved.
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 44, len(boxes) = 364. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to /kaggle/working/runs/detect/yolov9t/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 221 weight(decay=0.0), 228 weight(decay=0.0005), 227 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/detect/yolov9t
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.68G      1.823      3.541      1.657         18        640: 100% ━━━━━━━━━━━━ 80/80 2.9it/s 27.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.3it/s 2.3s0.2s
#                    all        365        364      0.248      0.107      0.113     0.0499
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.92G      1.719      2.828      1.611         20        640: 100% ━━━━━━━━━━━━ 80/80 3.3it/s 24.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.4it/s 2.2s0.2s
#                    all        365        364     0.0791      0.118     0.0571       0.02
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.92G      1.706      2.505      1.618         28        640: 100% ━━━━━━━━━━━━ 80/80 3.4it/s 23.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.6it/s 2.1s0.2s
#                    all        365        364       0.17      0.253      0.116      0.045
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.92G      1.696      2.322      1.595         19        640: 100% ━━━━━━━━━━━━ 80/80 3.4it/s 23.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.8it/s 2.1s0.2s
#                    all        365        364      0.286      0.137      0.111     0.0547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.92G      1.686      2.244      1.598         22        640: 100% ━━━━━━━━━━━━ 80/80 3.4it/s 23.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.6it/s 2.2s0.2s
#                    all        365        364      0.161      0.294      0.128     0.0533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.92G      1.649      2.132      1.581         19        640: 100% ━━━━━━━━━━━━ 80/80 3.4it/s 23.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.8it/s 2.1s0.2s
#                    all        365        364      0.256      0.343      0.201      0.086
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      2.92G      1.632      2.071      1.592         22        640: 100% ━━━━━━━━━━━━ 80/80 3.3it/s 24.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.9it/s 2.0s0.2s
#                    all        365        364      0.298      0.398      0.282      0.139
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.92G      1.566      2.015      1.527         19        640: 100% ━━━━━━━━━━━━ 80/80 3.4it/s 23.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.4it/s 2.2s0.2s
#                    all        365        364      0.404        0.4       0.32      0.146
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.92G      1.556          2      1.542         18        640: 100% ━━━━━━━━━━━━ 80/80 3.3it/s 24.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.0it/s 2.0s0.2s
#                    all        365        364      0.341      0.413      0.327      0.166
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      2.92G      1.547      1.962      1.536         14        640: 100% ━━━━━━━━━━━━ 80/80 3.3it/s 24.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.8it/s 2.1s0.2s
#                    all        365        364      0.326      0.489      0.299      0.145
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.92G      1.515       1.94      1.475         18        640: 100% ━━━━━━━━━━━━ 80/80 3.4it/s 23.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.7it/s 2.1s0.2s
#                    all        365        364      0.323       0.44      0.325      0.154
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.92G      1.548      1.866      1.483         21        640: 100% ━━━━━━━━━━━━ 80/80 3.4it/s 23.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.7it/s 2.1s0.2s
#                    all        365        364      0.435      0.401      0.363      0.177
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      2.92G      1.491      1.878      1.467         22        640: 100% ━━━━━━━━━━━━ 80/80 3.4it/s 23.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.9it/s 2.0s0.2s
#                    all        365        364      0.403      0.442       0.37      0.194
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      2.92G       1.47      1.842      1.437         24        640: 100% ━━━━━━━━━━━━ 80/80 3.4it/s 23.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.9it/s 2.0s0.2s
#                    all        365        364      0.467      0.418      0.435      0.228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      2.92G      1.472      1.794      1.451         18        640: 100% ━━━━━━━━━━━━ 80/80 3.4it/s 23.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.9it/s 2.1s0.2s
#                    all        365        364      0.419      0.451      0.422      0.237
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      2.92G      1.468      1.806      1.431         22        640: 100% ━━━━━━━━━━━━ 80/80 3.4it/s 23.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.0it/s 2.0s0.2s
#                    all        365        364      0.376      0.481      0.401      0.221
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      2.92G      1.419      1.769      1.396         20        640: 100% ━━━━━━━━━━━━ 80/80 3.4it/s 23.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.6it/s 2.1s0.2s
#                    all        365        364       0.41      0.393      0.363      0.192
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      2.92G      1.456      1.753      1.431         16        640: 100% ━━━━━━━━━━━━ 80/80 3.4it/s 23.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.7it/s 2.1s0.2s
#                    all        365        364      0.467      0.489      0.447      0.233
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      2.92G      1.438       1.75      1.421         22        640: 100% ━━━━━━━━━━━━ 80/80 3.4it/s 23.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6
640: 100% ━━━━━━━━━━━━ 80/80 3.4it/s 23.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.1it/s 2.0s0.2s
#                    all        365        364      0.688       0.69      0.721      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      2.93G     0.9836     0.9271      1.121         20        640: 100% ━━━━━━━━━━━━ 80/80 3.4it/s 23.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.9it/s 2.0s0.2s
#                    all        365        364      0.676      0.689       0.71      0.441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      2.93G      1.019     0.9459       1.13         22        640: 100% ━━━━━━━━━━━━ 80/80 3.4it/s 23.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.1it/s 2.0s0.2s
#                    all        365        364      0.709      0.657      0.722      0.459
# Closing dataloader mosaic
# albumentations: ImageCompression.__init__() got an unexpected keyword argument 'quality_range'
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      2.93G      0.935     0.8425      1.083         12        640: 100% ━━━━━━━━━━━━ 80/80 3.2it/s 25.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.1it/s 2.0s0.2s
#                    all        365        364      0.651      0.696      0.713      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      2.93G     0.9201     0.8031      1.077         13        640: 100% ━━━━━━━━━━━━ 80/80 3.4it/s 23.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.0it/s 2.0s0.2s
#                    all        365        364       0.69      0.692      0.713      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      2.93G     0.9097     0.7982      1.062         12        640: 100% ━━━━━━━━━━━━ 80/80 3.5it/s 23.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.1it/s 2.0s0.2s
#                    all        365        364       0.68      0.687      0.729      0.463
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      2.93G     0.8964     0.7804      1.054         12        640: 100% ━━━━━━━━━━━━ 80/80 3.5it/s 23.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.1it/s 2.0s0.2s
#                    all        365        364      0.734      0.651      0.739      0.469
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      2.93G      0.901     0.7815      1.061         12        640: 100% ━━━━━━━━━━━━ 80/80 3.5it/s 23.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.1it/s 2.0s0.2s
#                    all        365        364      0.709      0.668      0.727      0.462
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      2.93G     0.8715     0.7436      1.054         12        640: 100% ━━━━━━━━━━━━ 80/80 3.5it/s 23.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.0it/s 2.0s0.2s
#                    all        365        364      0.698      0.701      0.737      0.471
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      2.93G     0.8763     0.7442       1.05         12        640: 100% ━━━━━━━━━━━━ 80/80 3.4it/s 23.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.0it/s 2.0s0.2s
#                    all        365        364      0.743      0.637      0.726      0.463
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      2.93G     0.8633     0.7322      1.046         11        640: 100% ━━━━━━━━━━━━ 80/80 3.5it/s 23.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.2it/s 1.9s0.2s
#                    all        365        364      0.686      0.696      0.731      0.471
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      2.93G     0.8686     0.7359      1.041         11        640: 100% ━━━━━━━━━━━━ 80/80 3.4it/s 23.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.1it/s 2.0s0.2s
#                    all        365        364      0.721      0.668      0.734      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      2.93G      0.865     0.7199      1.046         13        640: 100% ━━━━━━━━━━━━ 80/80 3.5it/s 23.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 6.1it/s 2.0s0.2s
#                    all        365        364      0.719      0.673      0.734      0.469
#
# 100 epochs completed in 0.731 hours.
# Optimizer stripped from /kaggle/working/runs/detect/yolov9t/weights/last.pt, 4.6MB
# Optimizer stripped from /kaggle/working/runs/detect/yolov9t/weights/best.pt, 4.6MB
#
# Validating /kaggle/working/runs/detect/yolov9t/weights/best.pt...
# Ultralytics 8.3.235 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLOv9t summary (fused): 197 layers, 1,970,979 parameters, 0 gradients, 7.6 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.8it/s 4.2s0.2s
#                    all        365        364      0.724      0.668      0.734      0.475
# Speed: 1.1ms preprocess, 4.6ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to /kaggle/working/runs/detect/yolov9t

# %%
Image.open("/kaggle/working/runs/detect/yolov9t/results.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2400x1200>

# %%
# Export and Save Model for further uses
import shutil

# Path of model (best.pt)
# Normally at: runs/detect/{name}/weights/best.pt
best_model_path = "runs/detect/yolov9t/weights/best.pt"
output_model_name = "yolov9t_best_model.pt"

if os.path.exists(best_model_path):
    # Copy to path for easier to download/use
    shutil.copy(best_model_path, output_model_name)
    print(f"Successfully! Saved model at: {output_model_name}")
    print("You can use this model for Prediction.")
else:
    print("Model not found, please check the path.")

# (Optional) If you want Export to other format (e.g., ONNX)
# success = model.export(format='onnx')
# Out:
# Successfully! Saved model at: yolov9t_best_model.pt
# You can use this model for Prediction.

# %%
# Validate on the 'test' split specifically
metrics = model.val(split='test')
# Out:
# Ultralytics 8.3.235 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLOv9t summary (fused): 197 layers, 1,970,979 parameters, 0 gradients, 7.6 GFLOPs
# val: Fast image access ✅ (ping: 1.6±0.2 ms, read: 70.3±35.6 MB/s, size: 27.8 KB)
# val: Scanning /kaggle/input/the-drug-name-detection-dataset/test/labels... 182 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 182/182 638.1it/s 0.3s0.2s
# WARNING ⚠️ val: Cache directory /kaggle/input/the-drug-name-detection-dataset/test is not writable, cache not saved.
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 25, len(boxes) = 182. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.3it/s 3.6s0.1s
#                    all        182        182       0.73      0.742      0.739      0.468
# Speed: 2.7ms preprocess, 6.9ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val6

# %%
# Extract key metrics
map50 = metrics.box.map50
map50_95 = metrics.box.map
precision = metrics.box.mp
recall = metrics.box.mr

# Calculate F1-Score manually (Harmonic Mean of Precision and Recall)
# Formula: F1 = 2 * (P * R) / (P + R)
f1_score = 0.0
if (precision + recall) > 0:
    f1_score = 2 * (precision * recall) / (precision + recall)

print("\n" + "="*40)
print("   MODEL PERFORMANCE METRICS on {TEST SET}")
print("="*40)
print(f"mAP@50       : {map50:.4f}")
print(f"mAP@50-95    : {map50_95:.4f}")
print(f"Precision    : {precision:.4f}")
print(f"Recall       : {recall:.4f}")
print(f"F1-Score     : {f1_score:.4f}")
print("="*40 + "\n")
# Out:
# ========================================
#    MODEL PERFORMANCE METRICS on {TEST SET}
# ========================================
# mAP@50       : 0.7390
# mAP@50-95    : 0.4683
# Precision    : 0.7295
# Recall       : 0.7418
# F1-Score     : 0.7356
# ========================================

# %% [markdown]
# # <div style="border-radius:10px; border:#E75480 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:center">Predict Test Data</div>

# %%
paths = glob.glob("/kaggle/input/the-drug-name-detection-dataset/test/images/*")

# %%
n = 10
results = model.predict(paths[:n])
for i in range(n):
    r = results[i]
    img = Image.fromarray(r.plot())
    plt.figure(dpi=100)
    plt.imshow(img)
    plt.axis("off")
    plt.tight_layout()
    plt.show()
# Out:
# 0: 640x640 3 drug-names, 7.9ms
# 1: 640x640 1 drug-name, 7.9ms
# 2: 640x640 1 drug-name, 7.9ms
# 3: 640x640 1 drug-name, 7.9ms
# 4: 640x640 1 drug-name, 7.9ms
# 5: 640x640 2 drug-names, 7.9ms
# 6: 640x640 1 drug-name, 7.9ms
# 7: 640x640 2 drug-names, 7.9ms
# 8: 640x640 2 drug-names, 7.9ms
# 9: 640x640 2 drug-names, 7.9ms
# Speed: 1.7ms preprocess, 7.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
