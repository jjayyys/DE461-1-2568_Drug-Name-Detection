# %% [markdown]
# # <center>「YOLO12n」The Drug Name Detection Dataset</center>
# ### <center>If you feel my notebook helpful, support with one upvote, thank you👍</center>

# %% [markdown]
# # <div style="border-radius:10px; border:#E75480 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:center">Import Libraries</div>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install ultralytics --quiet

# %%
import os
import yaml
import glob
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="darkgrid", font="SimHei", rc={"axes.unicode_minus":False})

import torch
from ultralytics import YOLO

from PIL import Image

seed = 1
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

# %% [markdown]
# # <div style="border-radius:10px; border:#E75480 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:center">Modeling</div>

# %%
model = YOLO("yolo12n.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo12n.pt to 'yolo12n.pt': 100% ━━━━━━━━━━━━ 5.3MB 66.4MB/s 0.1s

# %%
config = {
    "path": "/kaggle/input/the-drug-name-detection-dataset",
    "train": "/kaggle/input/the-drug-name-detection-dataset/train",
    "val": "/kaggle/input/the-drug-name-detection-dataset/valid",
    "test": "/kaggle/input/the-drug-name-detection-dataset/test",
    "nc": 1,
    "names": ["drug-name"],
}

with open("data.yaml", "w") as file:
    yaml.dump(config, file, default_flow_style=False)

# %%
# !wandb disabled
# Out:
# W&B disabled.

# %%
results = model.train(data="data.yaml", epochs=100, save_period=10, seed=seed, name="yolo12n")
# Out:
# Ultralytics 8.3.235 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo12n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolo12n, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/yolo12n, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=1, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# 2025-12-06 17:57:47,673	INFO util.py:129 -- Outdated packages:
#   ipywidgets==7.7.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 2025-12-06 17:57:47,839	INFO util.py:129 -- Outdated packages:
#   ipywidgets==7.7.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  2    180864  ultralytics.nn.modules.block.A2C2f           [128, 128, 2, True, 4]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  2    689408  ultralytics.nn.modules.block.A2C2f           [256, 256, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1     86912  ultralytics.nn.modules.block.A2C2f           [384, 128, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1     24000  ultralytics.nn.modules.block.A2C2f           [256, 64, 1, False, -1]
#  15                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1     74624  ultralytics.nn.modules.block.A2C2f           [192, 128, 1, False, -1]
#  18                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  21        [14, 17, 20]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLOv12n summary: 272 layers, 2,568,243 parameters, 2,568,227 gradients, 6.5 GFLOPs
#
# Transferred 640/691 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 88.4±26.3 MB/s, size: 36.4 KB)
# train: Scanning /kaggle/input/the-drug-name-detection-dataset/train/labels... 1276 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1276/1276 978.9it/s 1.3s0.1s
# WARNING ⚠️ train: Cache directory /kaggle/input/the-drug-name-detection-dataset/train is not writable, cache not saved.
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 182, len(boxes) = 1277. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# albumentations: ImageCompression.__init__() got an unexpected keyword argument 'quality_range'
# val: Fast image access ✅ (ping: 2.2±1.1 ms, read: 55.7±15.0 MB/s, size: 27.1 KB)
# val: Scanning /kaggle/input/the-drug-name-detection-dataset/valid/labels... 365 images, 2 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 365/365 363.7it/s 1.0s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/the-drug-name-detection-dataset/valid is not writable, cache not saved.
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 44, len(boxes) = 364. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to /kaggle/working/runs/detect/yolo12n/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 113 weight(decay=0.0), 120 weight(decay=0.0005), 119 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/runs/detect/yolo12n
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      3.39G       1.93       3.79      1.632         18        640: 100% ━━━━━━━━━━━━ 80/80 3.2it/s 25.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 4.9it/s 2.5s0.2s
#                    all        365        364      0.189      0.157     0.0788     0.0314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      3.64G      1.978      3.158      1.759         20        640: 100% ━━━━━━━━━━━━ 80/80 3.5it/s 22.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.5it/s 2.2s0.2s
#                    all        365        364    0.00456      0.179    0.00233   0.000691
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      3.64G      1.937      2.767      1.769         28        640: 100% ━━━━━━━━━━━━ 80/80 3.6it/s 22.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.1it/s 2.3s0.2s
#                    all        365        364     0.0691      0.181     0.0385     0.0119
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      3.64G      1.898      2.508      1.723         19        640: 100% ━━━━━━━━━━━━ 80/80 3.6it/s 22.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.7it/s 2.1s0.2s
#                    all        365        364      0.112       0.14     0.0485     0.0185
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      3.64G      1.856      2.431      1.683         22        640: 100% ━━━━━━━━━━━━ 80/80 3.6it/s 22.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.6it/s 2.1s0.2s
#                    all        365        364      0.209      0.324      0.163     0.0607
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      3.64G       1.81      2.296      1.654         19        640: 100% ━━━━━━━━━━━━ 80/80 3.6it/s 22.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.7it/s 2.1s0.2s
#                    all        365        364      0.262      0.282      0.198     0.0798
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      3
0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 5.9it/s 2.0s0.2s
#                    all        365        364      0.668      0.673      0.693      0.436
#
# 100 epochs completed in 0.685 hours.
# Optimizer stripped from /kaggle/working/runs/detect/yolo12n/weights/last.pt, 5.5MB
# Optimizer stripped from /kaggle/working/runs/detect/yolo12n/weights/best.pt, 5.5MB
#
# Validating /kaggle/working/runs/detect/yolo12n/weights/best.pt...
# Ultralytics 8.3.235 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLOv12n summary (fused): 159 layers, 2,556,923 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 2.9it/s 4.2s0.2s
#                    all        365        364      0.672      0.653      0.688      0.439
# Speed: 0.9ms preprocess, 4.6ms inference, 0.0ms loss, 2.4ms postprocess per image
# Results saved to /kaggle/working/runs/detect/yolo12n

# %%
Image.open("/kaggle/working/runs/detect/yolo12n/results.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2400x1200>

# %%
# Export and Save Model for further uses
import shutil

# Path of model (best.pt)
# Normally at: runs/detect/{name}/weights/best.pt
best_model_path = "runs/detect/yolo12n/weights/best.pt"
output_model_name = "yolo12n_best_model.pt"

if os.path.exists(best_model_path):
    # Copy to path for easier to download/use
    shutil.copy(best_model_path, output_model_name)
    print(f"Successfully! Saved model at: {output_model_name}")
    print("You can use this model for Prediction.")
else:
    print("Model not found, please check the path.")

# (Optional) If you want Export to other format (e.g., ONNX)
# success = model.export(format='onnx')
# Out:
# Successfully! Saved model at: yolo12n_best_model.pt
# You can use this model for Prediction.

# %%
# Validate on the 'test' split specifically
metrics = model.val(split='test')
# Out:
# Ultralytics 8.3.235 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLOv12n summary (fused): 159 layers, 2,556,923 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 2.9±2.3 ms, read: 71.8±37.3 MB/s, size: 27.8 KB)
# val: Scanning /kaggle/input/the-drug-name-detection-dataset/test/labels... 182 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 182/182 619.4it/s 0.3s0.2s
# WARNING ⚠️ val: Cache directory /kaggle/input/the-drug-name-detection-dataset/test is not writable, cache not saved.
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 25, len(boxes) = 182. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.2it/s 3.8s0.1s
#                    all        182        182      0.658      0.612      0.658      0.427
# Speed: 2.5ms preprocess, 7.1ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val5

# %%
# Extract key metrics
map50 = metrics.box.map50
map50_95 = metrics.box.map
precision = metrics.box.mp
recall = metrics.box.mr

# Calculate F1-Score manually (Harmonic Mean of Precision and Recall)
# Formula: F1 = 2 * (P * R) / (P + R)
f1_score = 0.0
if (precision + recall) > 0:
    f1_score = 2 * (precision * recall) / (precision + recall)

print("\n" + "="*40)
print("   MODEL PERFORMANCE METRICS on {TEST SET}")
print("="*40)
print(f"mAP@50       : {map50:.4f}")
print(f"mAP@50-95    : {map50_95:.4f}")
print(f"Precision    : {precision:.4f}")
print(f"Recall       : {recall:.4f}")
print(f"F1-Score     : {f1_score:.4f}")
print("="*40 + "\n")
# Out:
# ========================================
#    MODEL PERFORMANCE METRICS on {TEST SET}
# ========================================
# mAP@50       : 0.6581
# mAP@50-95    : 0.4267
# Precision    : 0.6576
# Recall       : 0.6120
# F1-Score     : 0.6340
# ========================================

# %% [markdown]
# # <div style="border-radius:10px; border:#E75480 solid; padding: 15px; background-color: #FFFAF0; font-size:100%; text-align:center">Predict Test Data</div>

# %%
paths = glob.glob("/kaggle/input/the-drug-name-detection-dataset/test/images/*")

# %%
n = 10
results = model.predict(paths[:n])
for i in range(n):
    r = results[i]
    img = Image.fromarray(r.plot())
    plt.figure(dpi=100)
    plt.imshow(img)
    plt.axis("off")
    plt.tight_layout()
    plt.show()
# Out:
# 0: 640x640 2 drug-names, 7.6ms
# 1: 640x640 2 drug-names, 7.6ms
# 2: 640x640 1 drug-name, 7.6ms
# 3: 640x640 1 drug-name, 7.6ms
# 4: 640x640 1 drug-name, 7.6ms
# 5: 640x640 (no detections), 7.6ms
# 6: 640x640 1 drug-name, 7.6ms
# 7: 640x640 1 drug-name, 7.6ms
# 8: 640x640 2 drug-names, 7.6ms
# 9: 640x640 1 drug-name, 7.6ms
# Speed: 1.7ms preprocess, 7.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
